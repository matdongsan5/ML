# %%
import pandas as pd
import numpy as np
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
## 데이터셋, 데이터로더 관련 모듈
from torch.nn.utils.rnn import pad_sequence
## 데이터 길이 맞추기

## 토커나이저, 단어사전 관련 모듈
from torchtext.data.utils import get_tokenizer              ## 토커나이저 인스턴스 추출
from torchtext.vocab import build_vocab_from_iterator       ## 데이터셋에서 단어사전 생성 함수
from nltk.corpus import stopwords                           ## 불용어 데이터셋
import nltk
from nltk.tokenize import word_tokenize

# %%
import stanza
stanza.download("ko")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json: 367kB [00:00, 25.4MB/s]
# 2025-04-14 19:11:28 INFO: Downloading default packages for language: ko (Korean) ...
# 2025-04-14 19:11:29 INFO: File exists: C:\Users\kdt\stanza_resources\ko\default.zip
# 2025-04-14 19:11:30 INFO: Finished downloading models and saved to C:\Users\kdt\stanza_resources.

# %%
import spacy_stanza

# 한국어 파이프라인 불러오기
nlp = spacy_stanza.load_pipeline("ko")

# 테스트 문장 분석
doc = nlp("형, 나 지금 너무 떨려.")

for token in doc:
    print(token.text, token.pos_, token.lemma_)
# Out:
# 2025-04-14 19:11:30 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json: 367kB [00:00, 45.7MB/s]
# 2025-04-14 19:11:30 INFO: Loading these models for language: ko (Korean):
# ==============================
# | Processor | Package        |
# ------------------------------
# | tokenize  | kaist          |
# | pos       | kaist_nocharlm |
# | lemma     | kaist_nocharlm |
# | depparse  | kaist_nocharlm |
# ==============================
#
# 2025-04-14 19:11:30 WARNING: GPU requested, but is not available!
# 2025-04-14 19:11:30 INFO: Using device: cpu
# 2025-04-14 19:11:30 INFO: Loading: tokenize
# 2025-04-14 19:11:30 INFO: Loading: pos
# 2025-04-14 19:11:30 INFO: Loading: lemma
# 2025-04-14 19:11:30 INFO: Loading: depparse
# 2025-04-14 19:11:31 INFO: Done loading processors!
# 형 NOUN 형
# , PUNCT ,
# 나 PRON 나
# 지금 NOUN 지금
# 너무 ADV 너무
# 떨려 VERB 떨리+어
# . PUNCT .

# %%
DF00 = pd.DataFrame()
flist = os.listdir('./_data/0010')
flist = [ i for i in flist if i[-3:]=='csv']
print(flist)
for i in flist:
    temDF = pd.read_csv('./_data/0010/'+i, encoding='utf-8')
    print(i)
    DF00 = pd.concat((DF00, temDF), join='outer')
# Out:
# ['고양이를_부탁해_대사.csv', '공동경비구역JSA_시나리오.csv', '미녀는 괴로워.csv', '엽기적인_그녀.csv']
# 고양이를_부탁해_대사.csv
# 공동경비구역JSA_시나리오.csv
# 미녀는 괴로워.csv
# 엽기적인_그녀.csv

# %%
DF80 = pd.DataFrame()
flist = os.listdir('./_data/8090')
flist = [ i for i in flist if i[-3:]=='csv']
print(flist)
for i in flist:
    temDF = pd.read_csv('./_data/8090/'+i, encoding='utf-8')
    print(i)
    DF80 = pd.concat((DF80, temDF), join='outer')
# Out:
# ['sunny.csv', '살인의_추억.csv', '화려한휴가.csv']
# sunny.csv
# 살인의_추억.csv
# 화려한휴가.csv

# %%
DF90 = pd.DataFrame()
flist = os.listdir('./_data/9000')
flist = [ i for i in flist if i[-3:]=='csv']
print(flist)
for i in flist:
    temDF = pd.read_csv('./_data/9000/'+i, encoding='utf-8')
    print(i)
    DF90 = pd.concat((DF90, temDF), join='outer')
# Out:
# ['8월의_크리스마스.csv', '건축학개론_12.csv', '접속.csv', '초록 물고기.csv']
# 8월의_크리스마스.csv
# 건축학개론_12.csv
# 접속.csv
# 초록 물고기.csv

# %%
DF10 = pd.DataFrame()
flist = os.listdir('./_data/1020')
flist = [ i for i in flist if i[-3:]=='csv']
print(flist)
for i in flist[:-2]:
    temDF = pd.read_csv('./_data/1020/'+i, encoding='utf-8')
    print(i)
    DF10 = pd.concat((DF10, temDF), join='outer')
# Out:
# ['[대본]베테랑.csv', '끝까지간다.csv', '내부자들.csv', '부당거래.csv', '헬로우고스트_all.csv']
# [대본]베테랑.csv
# 끝까지간다.csv
# 내부자들.csv

# %%
DF10 = DF10.reset_index(drop=True)
DF00 = DF00.reset_index(drop=True)
DF80 = DF80.reset_index(drop=True)
DF90 = DF90.reset_index(drop=True)

# %%
DF80.shape, DF90.shape, DF00.shape, DF10.shape
# Out:
# ((2630, 2), (2519, 2), (2606, 2), (2900, 2))

# %%
DF80['age'] = '80'
DF90['age'] = '90'
DF00['age'] = '00'
DF10['age'] = '10'

# %%
resultDF = pd.concat((DF00,DF10,DF80,DF90))

# %%
resultDF = resultDF.drop(columns='Character')
resultDF = resultDF.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 resultDF = resultDF.drop(columns='Character')
#       2 resultDF = resultDF.reset_index(drop=True)
#
# File c:\Users\kdt\anaconda3\envs\NLP\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File c:\Users\kdt\anaconda3\envs\NLP\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Users\kdt\anaconda3\envs\NLP\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Users\kdt\anaconda3\envs\NLP\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Character'] not found in axis"

# %%
resultDF.to_csv('dataDF.csv', encoding='utf-8')
