# %%
## 모듈 로딩 및 데이터 진부
import cv2          # open cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = '../_data/_image/'

# %%
##[2] 이미지 로딩
file = img_path+'20250112144858_1.jpg'

myImg = cv2.imread(file, cv2.IMREAD_COLOR)

# %%
## 이미지 파일 로딩 => 흑백
grayImg = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
grayImg.shape
# Out:
# (717, 1178)

# %%
plt.imshow(grayImg)
plt.show()

# %%
save_filename = f"{img_path}img_gray.jpg"
save_filename
# Out:
# '../_data/_image/img_gray.jpg'

# %%
ret = cv2.imwrite(save_filename, grayImg)
ret
# Out:
# True
