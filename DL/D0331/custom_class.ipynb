# %% [markdown]
# [클래스 상속]

# %%
from collections import *

# %%
class A(abs.Set) :
    def __init__(self, num, msg):
        self.num = num;
        self.msg = msg;
        
    def printInfor(self):
        print(self.num)
        print(self.msg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 class A(abs.Set) :
#       2     def __init__(self, num, msg):
#       3         self.num = num;
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'Set'

# %%
class B(A):

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 a = [ [73, 80, 75], [93, 88, 93], [89, 91, 90], [96, 98, 100], [73, 66, 70] ]
# ----> 2 a.shape
#
# AttributeError: 'list' object has no attribute 'shape'
