# %% [markdown]
# - scikit-learn -> cpu만 고려. 그래서 병렬처리가 안됨.
# - gpu - 병렬처리. 그래픽, 음성, 멀티미디어, 3차원 데이터 빠르게 처리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1차식 ==> 로지스틱회귀와 유사. 모든 항에 가중치를 처리한뒤 최종 방정식.

# %% [markdown]
# - 다중분류 문제도 해결
#
# ![image.png](attachment:image.png)

# %% [markdown]
# FC LAYER
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# * Module 가변인자
# OrderedDict 형태도 가능
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
